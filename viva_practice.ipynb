# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
file_location=r"C:\Users\hp\Downloads\ads_coursework\datascienceexcel.csv"
sales_data=pd.read_csv(file_location)

# %%
sales_data
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
sales_data.drop(['salary','salary_currency'],axis=1)
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
sales_data
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
sales_data.drop(['salary','salary_currency'],axis=1, inplace=True)
sales_data
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
"""
new_data={
'work_year': 2,
    'experience_level': 'Entry-level',
    'employment_type': 'Full-time',
    'job_title': 'Junior Software Developer',
    

     'employee_residence': 'Australia',
    'remote_ratio': 25,
    'company_location': 'Sydney',
    
}
df1= pd.DataFrame(new_data, index=[0])
"""
# Out:
# "\nnew_data={\n'work_year': 2,\n    'experience_level': 'Entry-level',\n    'employment_type': 'Full-time',\n    'job_title': 'Junior Software Developer',\n    \n\n     'employee_residence': 'Australia',\n    'remote_ratio': 25,\n    'company_location': 'Sydney',\n    \n}\ndf1= pd.DataFrame(new_data, index=[0])\n"

# %%
#sales_data.append(df1)

# %%
#sales_data.loc[len(sales_data)]=new_data

# %%
# Check for NaN values in each column
columnsWithNaN = sales_data.columns[sales_data.isna().any()].tolist()

print("Columns with NaN values:", columnsWithNaN)
# Out:
# Columns with NaN values: []

# %%
sales_data.dropna(inplace=True)

# %%
duplicates= sales_data.duplicated()
if duplicates.any():
    check_duplicated= sales_data[duplicates]
check_duplicated
# Out:
#       work_year experience_level employment_type           job_title  \
# 115        2023               SE              FT      Data Scientist
# 123        2023               SE              FT  Analytics Engineer
# 153        2023               MI              FT       Data Engineer
# 154        2023               MI              FT       Data Engineer
# 160        2023               SE              FT       Data Engineer
# ...         ...              ...             ...                 ...
# 3439       2022               MI              FT      Data Scientist
# 3440       2022               SE              FT       Data Engineer
# 3441       2022               SE              FT       Data Engineer
# 3586       2021               MI              FT       Data Engineer
# 3709       2021               MI              FT      Data Scientist
#
#       salary_in_usd employee_residence  remote_ratio company_location  \
# ...

# %%
sales_data.drop_duplicates()
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %%
unique_value = {col:sales_data[col].unique() for col in sales_data.columns}

for col, values in unique_value.items():
    print(f"Unique values in column '{col}': '{values}'")
# Out:
# Unique values in column 'work_year': '[2023 2022 2020 2021]'
# Unique values in column 'experience_level': '['SE' 'MI' 'EN' 'EX']'
# Unique values in column 'employment_type': '['FT' 'CT' 'FL' 'PT']'
# Unique values in column 'job_title': '['Principal Data Scientist' 'ML Engineer' 'Data Scientist'
#  'Applied Scientist' 'Data Analyst' 'Data Modeler' 'Research Engineer'
#  'Analytics Engineer' 'Business Intelligence Engineer'
#  'Machine Learning Engineer' 'Data Strategist' 'Data Engineer'
#  'Computer Vision Engineer' 'Data Quality Analyst'
#  'Compliance Data Analyst' 'Data Architect'
#  'Applied Machine Learning Engineer' 'AI Developer' 'Research Scientist'
#  'Data Analytics Manager' 'Business Data Analyst' 'Applied Data Scientist'
#  'Staff Data Analyst' 'ETL Engineer' 'Data DevOps Engineer' 'Head of Data'
#  'Data Science Manager' 'Data Manager' 'Machine Learning Researcher'
#  'Big Data Engineer' 'Data Specialist' 'Lead Data Analyst'
# ...

# %%
mapping={
'SE':'Senor level/export',
'MI': 'Medium Level/Intermediate',
    'EN': 'Entry Level',
    'EX': 'Executive Level'
}

sales_data.loc[:,'experience_level']=sales_data['experience_level'].replace(mapping)

# %%
sum(sales_data['salary_in_usd'])
# Out:
# 516576814

# %%
kutosis= sales_data['salary_in_usd'].kurt()
kutosis
# Out:
# 0.8340064594833612

# %%
df_num= sales_data.select_dtypes(['number'])
corr=df_num.corr()
corr
# Out:
#                work_year  salary_in_usd  remote_ratio
# work_year        1.00000       0.228290     -0.236430
# salary_in_usd    0.22829       1.000000     -0.064171
# remote_ratio    -0.23643      -0.064171      1.000000

# %%
job_counts = sales_data['job_title'].value_counts().reset_index()
job_counts.columns=['job_title', 'job_count']

top_15_job= job_counts.sort_values(by='job_count',ascending=False).head(15)

top_15_job
# Out:
#                      job_title  job_count
# 0                Data Engineer       1040
# 1               Data Scientist        840
# 2                 Data Analyst        612
# 3    Machine Learning Engineer        289
# 4           Analytics Engineer        103
# 5               Data Architect        101
# 6           Research Scientist         82
# 7         Data Science Manager         58
# 8            Applied Scientist         58
# 9            Research Engineer         37
# 10                 ML Engineer         34
# 11                Data Manager         29
# 12  Machine Learning Scientist         26
# 13     Data Science Consultant         24
# 14      Data Analytics Manager         22

# %%
job_titles= top_15_job['job_title']
job_counts= top_15_job['job_count']

plt.figure(figsize=(15,8))
bars=plt.bar(job_titles, job_counts, color='skyblue')
plt.xlabel('Job Title')
plt.ylabel('Top 15 Job Titles by Count')
plt.xticks(rotation=90)

for i, v in enumerate(job_counts):
    plt.text(i, v+10, str(v), ha='center', va='bottom', fontsize=9)
plt.show()

# %%
maxsalary_job= sales_data.groupby('job_title')[['salary_in_usd']].max()

highest_salaries= maxsalary_job.sort_values(by='salary_in_usd',ascending=False)
highest_salaries
# Out:
#                                     salary_in_usd
# job_title
# Research Scientist                         450000
# Data Analyst                               430967
# AI Scientist                               423834
# Applied Machine Learning Scientist         423000
# Principal Data Scientist                   416000
# ...                                           ...
# Principal Data Architect                    38154
# Compliance Data Analyst                     30000
# Staff Data Analyst                          15000
# Product Data Scientist                       8000
# Power BI Developer                           5409
#
# [93 rows x 1 columns]

# %%
plt.figure(figsize=(25,12))

highest_salaries.plot(kind='bar', color='skyblue')

plt.title('job with their highest salary')

plt.xlabel('Job Title')
plt.ylabel('Salary USD')
plt.xticks(rotation=90, ha='right')
plt.tight_layout()
plt.show()

# %%
job_titles_2=highest_salaries['job_title']
job_count_2=highest_salaries['salary_in_usd']

plt.figure(figsize=())
